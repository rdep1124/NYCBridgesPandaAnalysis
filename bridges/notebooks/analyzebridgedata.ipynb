# %%
import pandas as pd

# %%
bridge_data = pd.read_csv('../data/Copy of BridgeDataFrom National Bridge Inventory - Sheet1.csv')

bridge_data.head()
# Out:
# /var/folders/75/4nzp2myd4fb4xmcrl1k19g7w0000gn/T/ipykernel_16354/3913169110.py:1: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   bridge_data = pd.read_csv('../data/Copy of BridgeDataFrom National Bridge Inventory - Sheet1.csv')
#    1 - State Code 1 - State Name 8 - Structure Number  \
# 0              36      New York'              2200100
# 1              36      New York'              3300690
# 2              36      New York'              2270040
# 3              36      New York'              3300510
# 4              36      New York'              2261160
#
#                   22 - Owner Agency 3 - County Code  3 - County Name  \
# 0  Town or Township Highway Agency'            103'  Suffolk County'
# 1            County Highway Agency'            103'  Suffolk County'
# 2  Town or Township Highway Agency'            103'  Suffolk County'
# 3  Town or Township Highway Agency'            103'  Suffolk County'
# ...

# %%
bridge_data['3 - County Name'].unique()
# Out:
# array(["Suffolk County'", "Nassau County'", "Dutchess County'",
#        "Queens County'", "Richmond County'", "Westchester County'",
#        "Kings County'", "Bronx County'", "Putnam County'",
#        "New York County'", "or Reservation Agency'", "Rockland County'",
#        "Columbia County'", "Orange County'", "Rensselaer County'",
#        "Ulster County'", "Saratoga County'", "Washington County'",
#        "Greene County'", "Albany County'", "Sullivan County'",
#        "Warren County'", "Schenectady County'", "Delaware County'",
#        "Essex County'", "Schoharie County'", "Montgomery County'",
#        "Fulton County'", "Hamilton County'", "Clinton County'",
#        "Otsego County'", "Herkimer County'", "Franklin County'",
#        "Broome County'", "Oneida County'", "Chenango County'",
#        "Madison County'", "St. Lawrence County'", "Chemung County'",
#        "Lewis County'", "Tioga County'", "Cortland County'",
# ...

# %%
bridge_data['statenisl'] = bridge_data['3 - County Name'].str.contains("Richmond County'")
bridge_data['statenisl'].value_counts()
# Out:
# statenisl
# False    17410
# True       163
# Name: count, dtype: int64

# %%
si_bridge_data = bridge_data[bridge_data['statenisl'] == True]

si_bridge_data.head()
# Out:
#       1 - State Code 1 - State Name 8 - Structure Number  \
# 750               36      New York'              1067800
# 1913              36      New York'      00000000552121I
# 1926              36      New York'      00000000552121G
# 1929              36      New York'      00000000552121H
# 1933              36      New York'      00000000552121D
#
#           22 - Owner Agency 3 - County Code   3 - County Name 4 - Place Code  \
# 750   State Highway Agency'            085'  Richmond County'         51000'
# 1913  Local Toll Authority'            085'  Richmond County'         51000'
# 1926  Local Toll Authority'            085'  Richmond County'         51000'
# 1929  Local Toll Authority'            085'  Richmond County'         51000'
# 1933  Local Toll Authority'            085'  Richmond County'         51000'
#
#      City - InfoBridge Place Code City - InfoBridge Place Name  \
# 750                        51000'               New York city'
# ...
