# %%
import pandas as pd

# %%
bridge_data = pd.read_csv('../data/NY23BridgeInspectionData - For Analysis.csv')

bridge_data.head()
# Out:
# /var/folders/75/4nzp2myd4fb4xmcrl1k19g7w0000gn/T/ipykernel_17591/2493949755.py:1: DtypeWarning: Columns (7,36,38,39,71,73,96,98,102,107,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   bridge_data = pd.read_csv('../data/NY23BridgeInspectionData - For Analysis.csv')
#    STATE_CODE_001 STRUCTURE_NUMBER_008  RECORD_TYPE_005A  ROUTE_PREFIX_005B  \
# 0             NaN                  NaN               NaN                NaN
# 1            36.0              1000040               1.0                2.0
# 2             NaN                  NaN               NaN                NaN
# 3            36.0              1000090               1.0                2.0
# 4             NaN                  NaN               NaN                NaN
#
#    SERVICE_LEVEL_005C ROUTE_NUMBER_005D  DIRECTION_005E HIGHWAY_DISTRICT_002  \
# 0                 NaN               NaN             NaN                  NaN
# ...

# %%
bridge_data.columns
# Out:
# Index(['STATE_CODE_001', 'STRUCTURE_NUMBER_008', 'RECORD_TYPE_005A',
#        'ROUTE_PREFIX_005B', 'SERVICE_LEVEL_005C', 'ROUTE_NUMBER_005D',
#        'DIRECTION_005E', 'HIGHWAY_DISTRICT_002', 'COUNTY_CODE_003',
#        'PLACE_CODE_004',
#        ...
#        'BRIDGE_LEN_IND_112', 'SCOUR_CRITICAL_113', 'FUTURE_ADT_114',
#        'YEAR_OF_FUTURE_ADT_115', 'MIN_NAV_CLR_MT_116', 'FED_AGENCY',
#        'SUBMITTED_BY', 'BRIDGE_CONDITION', 'LOWEST_RATING', 'DECK_AREA'],
#       dtype='object', length=123)

# %%
bridge_data.sort_values(by="COUNTY_CODE_003")
# Out:
#        STATE_CODE_001 STRUCTURE_NUMBER_008  RECORD_TYPE_005A  \
# 1081             36.0              1007570               1.0
# 1083             36.0              1007580               1.0
# 1085             36.0              1007590               1.0
# 1087             36.0              1007610               1.0
# 2469             36.0              1015980               1.0
# ...               ...                  ...               ...
# 35136             NaN                  NaN               NaN
# 35138             NaN                  NaN               NaN
# 35140             NaN                  NaN               NaN
# 35142             NaN                  NaN               NaN
# 35144             NaN                  NaN               NaN
#
#        ROUTE_PREFIX_005B  SERVICE_LEVEL_005C ROUTE_NUMBER_005D  \
# 1081                 2.0                 1.0             0009W
# 1083                 2.0                 1.0             0009W
# ...

# %%
statenisl_bridges = bridge_data[bridge_data["COUNTY_CODE_003"] == 85].sort_values(by="COUNTY_CODE_003")
statenisl_bridges.head()
# Out:
#        STATE_CODE_001 STRUCTURE_NUMBER_008  RECORD_TYPE_005A  \
# 34607            36.0              5523051               1.0
# 34609            36.0              5523052               1.0
# 34611            36.0      00000000552305A               1.0
# 34613            36.0      00000000552305B               1.0
# 34615            36.0      00000000552305C               1.0
#
#        ROUTE_PREFIX_005B  SERVICE_LEVEL_005C ROUTE_NUMBER_005D  \
# 34607                1.0                 1.0               278
# 34609                1.0                 1.0               278
# 34611                1.0                 1.0               278
# 34613                1.0                 1.0               278
# 34615                1.0                 1.0               278
#
#        DIRECTION_005E HIGHWAY_DISTRICT_002  COUNTY_CODE_003  PLACE_CODE_004  \
# 34607             0.0                   N5             85.0         51000.0
# ...

# %%
bad_bridges = statenisl_bridges[statenisl_bridges["LOWEST_RATING"] <= 6].sort_values(by="LOWEST_RATING")
bad_bridges.head()
# Out:
#        STATE_CODE_001 STRUCTURE_NUMBER_008  RECORD_TYPE_005A  \
# 18499            36.0              2249820               1.0
# 10719            36.0              1067730               1.0
# 10655            36.0              1067520               1.0
# 10657            36.0              1067530               1.0
# 34619            36.0              5523069               1.0
#
#        ROUTE_PREFIX_005B  SERVICE_LEVEL_005C ROUTE_NUMBER_005D  \
# 18499                5.0                 0.0                 0
# 10719                5.0                 0.0                 0
# 10655                5.0                 0.0                 0
# 10657                5.0                 0.0                 0
# 34619                2.0                 1.0               440
#
#        DIRECTION_005E HIGHWAY_DISTRICT_002  COUNTY_CODE_003  PLACE_CODE_004  \
# 18499             0.0                   N5             85.0         51000.0
# ...
